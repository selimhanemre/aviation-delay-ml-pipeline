# %%
spark.sql("DROP TABLE IF EXISTS aviation_project.silver_historical_weather")
spark.sql("DROP TABLE IF EXISTS aviation_project.silver_historical_flights")
spark.sql("DROP TABLE IF EXISTS aviation_project.silver_live_weather")
