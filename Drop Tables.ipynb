# %%
# Drop Bronze
# spark.sql("DROP TABLE IF EXISTS aviation_project.bronze_historical_weather")
spark.sql("DROP TABLE IF EXISTS aviation_project.bronze_historical_flights")

# !!! DONT DROP BRONZE LIVE F OR W TABLES (NO BACKUP) !!!

# %%
# Drop Silver
spark.sql("DROP TABLE IF EXISTS aviation_project.silver_historical_weather")
spark.sql("DROP TABLE IF EXISTS aviation_project.silver_historical_flights")
spark.sql("DROP TABLE IF EXISTS aviation_project.silver_live_weather")
spark.sql("DROP TABLE IF EXISTS aviation_project.silver_live_flights")

# %%
# Drop Gold
spark.sql("DROP TABLE IF EXISTS aviation_project.gold_master_dataset")
